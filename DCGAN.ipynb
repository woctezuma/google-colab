# %% [markdown]
# # DCGAN
#
# Reference: https://github.com/carpedm20/DCGAN-tensorflow

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from pathlib import Path
import os

os.chdir('/content/gdrive/My Drive/download-steam-banners/')

# !ls
# Out:
# app_ids.txt	   data		     images	   samples
# banner_matrix.npy  DCGAN-tensorflow  images_steam  saved_model
# checkpoint	   features	     logs	   saved_model_steam

# %%
from keras.preprocessing.image import load_img
from numpy.random import randint
import glob

# %%
data_dir = 'data/'
image_names = glob.glob(data_dir+'*.jpg')  
image_name = image_names[randint(0, len(image_names))]   
image = load_img(image_name, target_size=(215, 460))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=460x215 at 0x7F3155993080>

# %%
# !rm -rf DCGAN-tensorflow/

# !git clone https://github.com/woctezuma/DCGAN-tensorflow.git
  
# Caveat: https://github.com/carpedm20/DCGAN-tensorflow/issues/162#issuecomment-315519747
# Out:
# Cloning into 'DCGAN-tensorflow'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 1090 (delta 0), reused 0 (delta 0), pack-reused 1087
# Receiving objects: 100% (1090/1090), 77.97 MiB | 9.82 MiB/s, done.
# Resolving deltas: 100% (614/614), done.
# Checking out files: 100% (90/90), done.

# %%
# !python DCGAN-tensorflow/main.py --dataset data --data_dir "/content/gdrive/My Drive/download-steam-banners/" --input_height=215 --output_height=215 --train
# Out:
# {'batch_size': <absl.flags._flag.Flag object at 0x7f9775530080>,
#  'beta1': <absl.flags._flag.Flag object at 0x7f9775541f98>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7f97613fb198>,
#  'crop': <absl.flags._flag.BooleanFlag object at 0x7f97613fb358>,
#  'data_dir': <absl.flags._flag.Flag object at 0x7f97613fb208>,
#  'dataset': <absl.flags._flag.Flag object at 0x7f97613fb080>,
#  'epoch': <absl.flags._flag.Flag object at 0x7f97ca80c080>,
#  'generate_test_images': <absl.flags._flag.Flag object at 0x7f97613fb470>,
#  'h': <tensorflow.python.platform.app._HelpFlag object at 0x7f97613fb4a8>,
#  'help': <tensorflow.python.platform.app._HelpFlag object at 0x7f97613fb4a8>,
#  'helpfull': <tensorflow.python.platform.app._HelpfullFlag object at 0x7f97613fb550>,
#  'helpshort': <tensorflow.python.platform.app._HelpshortFlag object at 0x7f97613fb5c0>,
#  'input_fname_pattern': <absl.flags._flag.Flag object at 0x7f97613fb0f0>,
#  'input_height': <absl.flags._flag.Flag object at 0x7f9761444e80>,
#  'input_width': <absl.flags._flag.Flag object at 0x7f97613f1eb8>,
#  'learning_rate': <absl.flags._flag.Flag object at 0x7f97b7ac46d8>,
#  'output_height': <absl.flags._flag.Flag object at 0x7f97613f1f28>,
#  'output_width': <absl.flags._flag.Flag object at 0x7f97613f1fd0>,
#  'sample_dir': <absl.flags._flag.Flag object at 0x7f97613fb278>,
#  'train': <absl.flags._flag.BooleanFlag object at 0x7f97613fb2b0>,
#  'train_size': <absl.flags._flag.Flag object at 0x7f977554e3c8>,
#  'visualize': <absl.flags._flag.BooleanFlag object at 0x7f97613fb3c8>}
# 2019-02-15 11:16:57.293520: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-02-15 11:16:57.293774: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x199aec0 executing computations on platform Host. Devices:
# 2019-02-15 11:16:57.293852: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-02-15 11:16:57.366866: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-02-15 11:16:57.367706: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x199a7e0 executing computations on platform CUDA. Devices:
# 2019-02-15 11:16:57.367749: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-02-15 11:16:57.368140: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 10.43GiB
# 2019-02-15 11:16:57.368226: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-02-15 11:16:57.774585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-02-15 11:16:57.774655: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-02-15 11:16:57.774685: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-02-15 11:16:57.775020: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10103 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# ---------
# Variables: name (type shape) [size]
# ---------
# generator/g_h0_lin/Matrix:0 (float32_ref 100x100352) [10035200, bytes: 40140800]
# generator/g_h0_lin/bias:0 (float32_ref 100352) [100352, bytes: 401408]
# generator/g_bn0/beta:0 (float32_ref 512) [512, bytes: 2048]
# generator/g_bn0/gamma:0 (float32_ref 512) [512, bytes: 2048]
# generator/g_h1/w:0 (float32_ref 5x5x256x512) [3276800, bytes: 13107200]
# generator/g_h1/biases:0 (float32_ref 256) [256, bytes: 1024]
# generator/g_bn1/beta:0 (float32_ref 256) [256, bytes: 1024]
# generator/g_bn1/gamma:0 (float32_ref 256) [256, bytes: 1024]
# generator/g_h2/w:0 (float32_ref 5x5x128x256) [819200, bytes: 3276800]
# generator/g_h2/biases:0 (float32_ref 128) [128, bytes: 512]
# generator/g_bn2/beta:0 (float32_ref 128) [128, bytes: 512]
# generator/g_bn2/gamma:0 (float32_ref 128) [128, bytes: 512]
# generator/g_h3/w:0 (float32_ref 5x5x64x128) [204800, bytes: 819200]
# generator/g_h3/biases:0 (float32_ref 64) [64, bytes: 256]
# generator/g_bn3/beta:0 (float32_ref 64) [64, bytes: 256]
# generator/g_bn3/gamma:0 (float32_ref 64) [64, bytes: 256]
# generator/g_h4/w:0 (float32_ref 5x5x3x64) [4800, bytes: 19200]
# generator/g_h4/biases:0 (float32_ref 3) [3, bytes: 12]
# discriminator/d_h0_conv/w:0 (float32_ref 5x5x3x64) [4800, bytes: 19200]
# discriminator/d_h0_conv/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/d_h1_conv/w:0 (float32_ref 5x5x64x128) [204800, bytes: 819200]
# discriminator/d_h1_conv/biases:0 (float32_ref 128) [128, bytes: 512]
# discriminator/d_bn1/beta:0 (float32_ref 128) [128, bytes: 512]
# discriminator/d_bn1/gamma:0 (float32_ref 128) [128, bytes: 512]
# discriminator/d_h2_conv/w:0 (float32_ref 5x5x128x256) [819200, bytes: 3276800]
# discriminator/d_h2_conv/biases:0 (float32_ref 256) [256, bytes: 1024]
# discriminator/d_bn2/beta:0 (float32_ref 256) [256, bytes: 1024]
# discriminator/d_bn2/gamma:0 (float32_ref 256) [256, bytes: 1024]
# discriminator/d_h3_conv/w:0 (float32_ref 5x5x256x512) [3276800, bytes: 13107200]
# discriminator/d_h3_conv/biases:0 (float32_ref 512) [512, bytes: 2048]
# discriminator/d_bn3/beta:0 (float32_ref 512) [512, bytes: 2048]
# discriminator/d_bn3/gamma:0 (float32_ref 512) [512, bytes: 2048]
# discriminator/d_h4_lin/Matrix:0 (float32_ref 100352x1) [100352, bytes: 401408]
# discriminator/d_h4_lin/bias:0 (float32_ref 1) [1, bytes: 4]
# Total size of variables: 18852228
# Total bytes of variables: 75408912
#  [*] Reading checkpoints...
#  [*] Failed to find a checkpoint
#  [!] Load failed...
# 2019-02-15 11:17:39.347598: W tensorflow/core/framework/allocator.cc:124] Allocation of 191102976 exceeds 10% of system memory.
# 2019-02-15 11:17:39.505279: W tensorflow/core/framework/allocator.cc:124] Allocation of 191102976 exceeds 10% of system memory.
# 2019-02-15 11:17:39.947798: W tensorflow/core/framework/allocator.cc:124] Allocation of 191102976 exceeds 10% of system memory.
# 2019-02-15 11:17:40.009061: W tensorflow/core/framework/allocator.cc:124] Allocation of 191102976 exceeds 10% of system memory.
# 2019-02-15 11:17:40.123624: W tensorflow/core/framework/allocator.cc:124] Allocation of 191102976 exceeds 10% of system memory.
# 2019-02-15 11:17:48.166372: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# Epoch: [ 0/25] [   0/ 495] time: 42.7089, d_loss: 31.87764549, g_loss: 0.00000000
# Epoch: [ 0/25] [   1/ 495] time: 64.5440, d_loss: 25.48491287, g_loss: 0.00000002
# Epoch: [ 0/25] [   2/ 495] time: 88.3845, d_loss: 35.97853851, g_loss: 0.00000000
# Epoch: [ 0/25] [   3/ 495] time: 105.2090, d_loss: 26.77028656, g_loss: 0.00000001
# Epoch: [ 0/25] [   4/ 495] time: 131.4700, d_loss: 26.69604874, g_loss: 0.00000000
# Epoch: [ 0/25] [   5/ 495] time: 152.2580, d_loss: 25.90573120, g_loss: 0.00000012
# Epoch: [ 0/25] [   6/ 495] time: 175.1317, d_loss: 30.49734306, g_loss: 0.00000000
# Epoch: [ 0/25] [   7/ 495] time: 195.1738, d_loss: 23.57944298, g_loss: 0.00000004
# Epoch: [ 0/25] [   8/ 495] time: 229.7885, d_loss: 29.85603333, g_loss: 0.00000000
# Epoch: [ 0/25] [   9/ 495] time: 254.9675, d_loss: 34.34787369, g_loss: 0.00000000
# Epoch: [ 0/25] [  10/ 495] time: 275.6041, d_loss: 32.58396149, g_loss: 0.00000000
# Epoch: [ 0/25] [  11/ 495] time: 302.5123, d_loss: 37.31875992, g_loss: 0.00000000
# Epoch: [ 0/25] [  12/ 495] time: 319.9505, d_loss: 29.51583672, g_loss: 0.00000000
# Epoch: [ 0/25] [  13/ 495] time: 337.7333, d_loss: 35.67135620, g_loss: 0.00000000
# Epoch: [ 0/25] [  14/ 495] time: 359.1661, d_loss: 31.13955116, g_loss: 0.00000000
# Epoch: [ 0/25] [  15/ 495] time: 380.0769, d_loss: 37.66528320, g_loss: 0.00000000
# Epoch: [ 0/25] [  16/ 495] time: 403.0497, d_loss: 28.24128532, g_loss: 0.00000001
# Epoch: [ 0/25] [  17/ 495] time: 426.9269, d_loss: 30.85491180, g_loss: 0.00000083
# Epoch: [ 0/25] [  18/ 495] time: 446.4927, d_loss: 25.08443069, g_loss: 0.00000005
# Epoch: [ 0/25] [  19/ 495] time: 467.6497, d_loss: 28.57404709, g_loss: 0.00012945
# Epoch: [ 0/25] [  20/ 495] time: 488.1027, d_loss: 25.58689880, g_loss: 0.00000000
# Epoch: [ 0/25] [  21/ 495] time: 510.7176, d_loss: 11.11561966, g_loss: 0.59884298
# Epoch: [ 0/25] [  22/ 495] time: 530.9111, d_loss: 26.24504852, g_loss: 0.04818416
# Epoch: [ 0/25] [  23/ 495] time: 550.7582, d_loss: 16.20483398, g_loss: 0.04769493
# Epoch: [ 0/25] [  24/ 495] time: 569.5071, d_loss: 26.73394012, g_loss: 0.60937732
# Epoch: [ 0/25] [  25/ 495] time: 587.2674, d_loss: 17.07932472, g_loss: 4.10192871
# Epoch: [ 0/25] [  26/ 495] time: 604.7176, d_loss: 34.66198349, g_loss: 0.00000003
# Epoch: [ 0/25] [  27/ 495] time: 622.0434, d_loss: 9.41350174, g_loss: 3.94515562
# Epoch: [ 0/25] [  28/ 495] time: 641.2068, d_loss: 22.66421890, g_loss: 0.51807845
# Epoch: [ 0/25] [  29/ 495] time: 661.3493, d_loss: 20.04806137, g_loss: 0.46443346
# Epoch: [ 0/25] [  30/ 495] time: 682.6534, d_loss: 21.00540924, g_loss: 11.25775146
# Epoch: [ 0/25] [  31/ 495] time: 699.6999, d_loss: 27.46926308, g_loss: 0.00000104
# Epoch: [ 0/25] [  32/ 495] time: 715.2935, d_loss: 23.41695404, g_loss: 7.05911303
# Epoch: [ 0/25] [  33/ 495] time: 733.1043, d_loss: 19.46201515, g_loss: 0.00003468
# Epoch: [ 0/25] [  34/ 495] time: 753.8086, d_loss: 15.33135128, g_loss: 0.55140239
# Epoch: [ 0/25] [  35/ 495] time: 771.7382, d_loss: 14.74233723, g_loss: 0.06353889
# Epoch: [ 0/25] [  36/ 495] time: 790.8471, d_loss: 12.76167774, g_loss: 0.00026331
# Epoch: [ 0/25] [  37/ 495] time: 806.1529, d_loss: 14.95035362, g_loss: 4.11678219
# Epoch: [ 0/25] [  38/ 495] time: 823.6256, d_loss: 12.91039753, g_loss: 0.00109802
# Epoch: [ 0/25] [  39/ 495] time: 842.7631, d_loss: 9.02441216, g_loss: 0.51883566
# Epoch: [ 0/25] [  40/ 495] time: 859.3675, d_loss: 8.97684574, g_loss: 0.48608726
# Epoch: [ 0/25] [  41/ 495] time: 877.5615, d_loss: 12.35961628, g_loss: 0.00092937
# Epoch: [ 0/25] [  42/ 495] time: 898.0300, d_loss: 11.39869690, g_loss: 2.42175484
# Epoch: [ 0/25] [  43/ 495] time: 916.8591, d_loss: 8.12795067, g_loss: 0.18783826
# Epoch: [ 0/25] [  44/ 495] time: 936.5561, d_loss: 5.89879084, g_loss: 0.61750174
# Epoch: [ 0/25] [  45/ 495] time: 956.0872, d_loss: 5.80756760, g_loss: 0.33358550
# Traceback (most recent call last):
#   File "DCGAN-tensorflow/main.py", line 103, in <module>
#     tf.app.run()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/platform/app.py", line 125, in run
#     _sys.exit(main(argv))
#   File "DCGAN-tensorflow/main.py", line 86, in main
#     dcgan.train(FLAGS)
#   File "/content/gdrive/My Drive/download-steam-banners/DCGAN-tensorflow/model.py", line 220, in train
#     grayscale=self.grayscale) for batch_file in batch_files]
#   File "/content/gdrive/My Drive/download-steam-banners/DCGAN-tensorflow/model.py", line 220, in <listcomp>
#     grayscale=self.grayscale) for batch_file in batch_files]
#   File "/content/gdrive/My Drive/download-steam-banners/DCGAN-tensorflow/utils.py", line 29, in get_image
#     image = imread(image_path, grayscale)
#   File "/content/gdrive/My Drive/download-steam-banners/DCGAN-tensorflow/utils.py", line 41, in imread
#     img = cv2.imread(path)
# KeyboardInterrupt
