# %% [markdown]
# # DCGAN
#
# Reference: https://github.com/carpedm20/DCGAN-tensorflow

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from pathlib import Path
import os

os.chdir('/content/gdrive/My Drive/download-steam-banners/')

# !ls
# Out:
# app_ids.txt	   DCGAN-tensorflow  images_steam_dcgan  samples
# banner_matrix.npy  features	     images_steam_gan	 saved_model
# checkpoint	   images	     images_steam_wgan	 saved_model_steam
# data		   images_steam      logs

# %%
from keras.preprocessing.image import load_img
from numpy.random import randint
import glob
# Out:
# Using TensorFlow backend.

# %%
data_dir = 'data/'
image_names = glob.glob(data_dir+'*.jpg')  
image_name = image_names[randint(0, len(image_names))]   
print(image_name)
image = load_img(image_name, target_size=(215, 460))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=460x215 at 0x7F5848C4FEB8>

# %%
# !rm -rf DCGAN-tensorflow/

# !git clone https://github.com/woctezuma/DCGAN-tensorflow.git
  
# Caveat: https://github.com/carpedm20/DCGAN-tensorflow/issues/162#issuecomment-315519747
# Out:
# Cloning into 'DCGAN-tensorflow'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 1093 (delta 2), reused 0 (delta 0), pack-reused 1087
# Receiving objects: 100% (1093/1093), 77.97 MiB | 10.56 MiB/s, done.
# Resolving deltas: 100% (616/616), done.
# Checking out files: 100% (90/90), done.

# %%
# !python DCGAN-tensorflow/main.py --dataset data --data_dir "/content/gdrive/My Drive/download-steam-banners/" --input_height=215 --train --crop
# Out:
# {'batch_size': <absl.flags._flag.Flag object at 0x7f62eb3485c0>,
#  'beta1': <absl.flags._flag.Flag object at 0x7f62eb33fef0>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7f62d71f8048>,
#  'crop': <absl.flags._flag.BooleanFlag object at 0x7f62d71f8208>,
#  'data_dir': <absl.flags._flag.Flag object at 0x7f62d71f80b8>,
#  'dataset': <absl.flags._flag.Flag object at 0x7f62d71ecef0>,
#  'epoch': <absl.flags._flag.Flag object at 0x7f634060a0b8>,
#  'generate_test_images': <absl.flags._flag.Flag object at 0x7f62d71f8320>,
#  'h': <tensorflow.python.platform.app._HelpFlag object at 0x7f62d71f8358>,
#  'help': <tensorflow.python.platform.app._HelpFlag object at 0x7f62d71f8358>,
#  'helpfull': <tensorflow.python.platform.app._HelpfullFlag object at 0x7f62d71f8400>,
#  'helpshort': <tensorflow.python.platform.app._HelpshortFlag object at 0x7f62d71f8470>,
#  'input_fname_pattern': <absl.flags._flag.Flag object at 0x7f62d71ecf60>,
# ...

# %%
# !python DCGAN-tensorflow/main.py --dataset data --data_dir "/content/gdrive/My Drive/download-steam-banners/" --input_height=215 --crop
# Out:
# {'batch_size': <absl.flags._flag.Flag object at 0x7f4f70d096d8>,
#  'beta1': <absl.flags._flag.Flag object at 0x7f4f70cfff28>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7f4f5cb7a048>,
#  'crop': <absl.flags._flag.BooleanFlag object at 0x7f4f5cb7a208>,
#  'data_dir': <absl.flags._flag.Flag object at 0x7f4f5cb7a0b8>,
#  'dataset': <absl.flags._flag.Flag object at 0x7f4f5cb6fef0>,
#  'epoch': <absl.flags._flag.Flag object at 0x7f4fc5fcb0b8>,
#  'generate_test_images': <absl.flags._flag.Flag object at 0x7f4f5cb7a320>,
#  'h': <tensorflow.python.platform.app._HelpFlag object at 0x7f4f5cb7a358>,
#  'help': <tensorflow.python.platform.app._HelpFlag object at 0x7f4f5cb7a358>,
#  'helpfull': <tensorflow.python.platform.app._HelpfullFlag object at 0x7f4f5cb7a400>,
#  'helpshort': <tensorflow.python.platform.app._HelpshortFlag object at 0x7f4f5cb7a470>,
#  'input_fname_pattern': <absl.flags._flag.Flag object at 0x7f4f5cb6ff60>,
# ...
